# %%
x = 5000
x
# Out:
# 5000

# %%
id(x)
# Out:
# 2417510426064

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 2417510426064

# %%
x = 500
id(x)
# Out:
# 2226597902512

# %%
a = 10
id(a)
# Out:
# 140705817826504

# %%
a = 20
id(a)
# Out:
# 140705817826824

# %%
a = 10
id(a)
# Out:
# 140705817826504

# %%
number_of_students = 100

# %%
type(number_of_students)
# Out:
# int

# %%
pi = 3.14
type (pi)
# Out:
# float

# %%
result = True 
type(result)
# Out:
# bool

# %%
pi = "원주율"
type(pi)
# Out:
# str
