# %% [markdown]
# # 1장 3강

# %%
print ("Hello")
# Out:
# Hello

# %%
printe ("world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 printe ("world")
#
# NameError: name 'printe' is not defined

# %%
printe ("world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 printe ("world")
#
# NameError: name 'printe' is not defined

# %%
print ("world")
# Out:
# world

# %%
printe ("everyone")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 printe ("everyone")
#
# NameError: name 'printe' is not defined

# %%
print ("everyone")
# Out:
# everyone
