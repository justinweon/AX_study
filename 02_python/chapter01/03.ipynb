# %% [markdown]
# # 1장 3강

# %%
print ("Hello")

# %%
printe ("world")

# %%
printe ("world")

# %%
print ("world")

# %%
printe ("everyone")

# %%
print ("everyone")

# %%
print (money)

# %%
money = 5000

# %%
money = money +2000
print (money)
