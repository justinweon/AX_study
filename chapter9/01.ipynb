# %%
all([True, a, " "])

# %%
num = 10.56
print(round(num))
# Out:
# 11

# %%
num = 10.56
print(round(num,1))

import math

print(math.ceil(10.2))
print(math.floor(num))
# Out:
# 10.6
# 11
# 10

# %%
import statistics

nums = [1, 155, 20, 8, 7, 1000000]

print("average:", statistics.mean(nums), "median:", statistics.median(nums))
# Out:
# average 166698.5 median: 14.0
